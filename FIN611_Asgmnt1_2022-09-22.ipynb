# %%
#Load the dataset 'data_ml.csv' to python. (Tips: use parse date parameters for date column)
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data_ml.csv', parse_dates=['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283380 entries, 0 to 283379
# Data columns (total 99 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   stock_id                        283380 non-null  int64
#  1   date                            283380 non-null  datetime64[ns]
#  2   Advt_12M_Usd                    283380 non-null  float64
#  3   Advt_3M_Usd                     283380 non-null  float64
#  4   Advt_6M_Usd                     283380 non-null  float64
#  5   Asset_Turnover                  283380 non-null  float64
#  6   Bb_Yld                          283380 non-null  float64
#  7   Bv                              283380 non-null  float64
#  8   Capex_Ps_Cf                     283380 non-null  float64
#  9   Capex_Sales                     283380 non-null  float64
#  10  Cash_Div_Cf                     283380 non-null  float64
# ...

# %%
print(df)
# Out:
#         stock_id       date  Advt_12M_Usd  Advt_3M_Usd  Advt_6M_Usd  \
# 0             13 2006-12-31          0.25         0.33         0.27
# 1             13 2007-01-31          0.25         0.32         0.28
# 2             13 2007-02-28          0.26         0.30         0.30
# 3             17 2015-03-31          0.73         0.64         0.70
# 4             17 2015-04-30          0.72         0.62         0.66
# ...          ...        ...           ...          ...          ...
# 283375      1205 2004-05-31          0.97         0.97         0.98
# 283376      1205 2004-07-31          0.97         0.96         0.98
# 283377      1205 2004-08-31          0.97         0.96         0.97
# 283378      1205 2004-09-30          0.97         0.96         0.97
# 283379       292 2000-04-30          0.41         0.63         0.52
#
#         Asset_Turnover  Bb_Yld    Bv  Capex_Ps_Cf  Capex_Sales  ...  \
# 0                 0.22    0.33  0.01         0.13         0.84  ...
# ...

# %%
#Print all the column names of the data 'data_ml.csv'. 
list(data.columns)
# Out:
# ['stock_id',
#  'date',
#  'Advt_12M_Usd',
#  'Advt_3M_Usd',
#  'Advt_6M_Usd',
#  'Asset_Turnover',
#  'Bb_Yld',
#  'Bv',
#  'Capex_Ps_Cf',
#  'Capex_Sales',
#  'Cash_Div_Cf',
#  'Cash_Per_Share',
#  'Cf_Sales',
#  'Debtequity',
#  'Div_Yld',
#  'Dps',
#  'Ebit_Bv',
#  'Ebit_Noa',
#  'Ebit_Oa',
#  'Ebit_Ta',
#  'Ebitda_Margin',
#  'Eps',
#  'Eps_Basic',
#  'Eps_Basic_Gr',
#  'Eps_Contin_Oper',
#  'Eps_Dil',
#  'Ev',
#  'Ev_Ebitda',
#  'Fa_Ci',
#  'Fcf',
#  'Fcf_Bv',
#  'Fcf_Ce',
#  'Fcf_Margin',
#  'Fcf_Noa',
#  'Fcf_Oa',
#  'Fcf_Ta',
#  'Fcf_Tbv',
#  'Fcf_Toa',
#  'Fcf_Yld',
#  'Free_Ps_Cf',
#  'Int_Rev',
#  'Interest_Expense',
#  'Mkt_Cap_12M_Usd',
#  'Mkt_Cap_3M_Usd',
#  'Mkt_Cap_6M_Usd',
#  'Mom_11M_Usd',
#  'Mom_5M_Usd',
#  'Mom_Sharp_11M_Usd',
#  'Mom_Sharp_5M_Usd',
#  'Nd_Ebitda',
#  'Net_Debt',
#  'Net_Debt_Cf',
#  'Net_Margin',
#  'Netdebtyield',
#  'Ni',
#  'Ni_Avail_Margin',
#  'Ni_Oa',
#  'Ni_Toa',
#  'Noa',
#  'Oa',
#  'Ocf',
#  'Ocf_Bv',
#  'Ocf_Ce',
#  'Ocf_Margin',
# ...

# %%
#Print the top five rows of the data.
Top_five_rows = df.head()
print(Top_five_rows)
# Out:
#    stock_id       date  Advt_12M_Usd  Advt_3M_Usd  Advt_6M_Usd  \
# 0        13 2006-12-31          0.25         0.33         0.27
# 1        13 2007-01-31          0.25         0.32         0.28
# 2        13 2007-02-28          0.26         0.30         0.30
# 3        17 2015-03-31          0.73         0.64         0.70
# 4        17 2015-04-30          0.72         0.62         0.66
#
#    Asset_Turnover  Bb_Yld    Bv  Capex_Ps_Cf  Capex_Sales  ...  Total_Capital  \
# 0            0.22    0.33  0.01         0.13         0.84  ...           0.02
# 1            0.22    0.40  0.01         0.13         0.84  ...           0.02
# 2            0.22    0.15  0.01         0.13         0.84  ...           0.02
# 3            0.40    0.47  0.01         0.70         0.74  ...           0.40
# 4            0.40    0.46  0.01         0.70         0.74  ...           0.40
#
#    Total_Debt  Total_Debt_Capital  Total_Liabilities_Total_Assets  Vol1Y_Usd  \
# ...

# %%
#Print the descriptive statistics of the variables ‘Asset_Turnover', 'Interest_Expense', 
#'Eps', 'Net_Margin', 'Roa', 'Roe', 'Ta','Total_Debt', and 'R1M_Usd'

df[['Asset_Turnover', 'Interest_Expense', 'Eps', 'Net_Margin', 'Roa', 'Roe', 'Ta','Total_Debt', 'R1M_Usd']].describe()
# Out:
#        Asset_Turnover  Interest_Expense            Eps     Net_Margin  \
# count   283380.000000     283380.000000  283380.000000  283380.000000
# mean         0.502258          0.495831       0.502315       0.503903
# std          0.287403          0.275126       0.286798       0.288563
# min          0.010000          0.010000       0.010000       0.010000
# 25%          0.250000          0.270000       0.260000       0.250000
# 50%          0.500000          0.500000       0.500000       0.500000
# 75%          0.750000          0.720000       0.750000       0.750000
# max          1.000000          1.000000       1.000000       1.000000
#
#                  Roa            Roe             Ta     Total_Debt  \
# count  283380.000000  283380.000000  283380.000000  283380.000000
# mean        0.502904       0.497333       0.501350       0.501177
# std         0.286489       0.282200       0.288448       0.288317
# min         0.010000       0.010000       0.010000       0.010000
# ...

# %%
#Graphically show the relationship between the variables ‘Ta', and 'R1M_Usd'; and 'Total_Capital' and 'Total_Debt'. 
#Use proper axes and figure titles. (tip: use two separate Scatterplot graphs)

import matplotlib.pyplot as plt

data.plot.scatter(x='Ta', y='R1M_Usd', color='Red')
data.plot.scatter(x='Total_Capital', y='Total_Debt', color = 'Blue')
# Out:
# <AxesSubplot:xlabel='Total_Capital', ylabel='Total_Debt'>

# %%
sortbydate = df.sort_values(by='date', ascending = False, ignore_index=True)
print(sortbydate)
# Out:
#         stock_id       date  Advt_12M_Usd  Advt_3M_Usd  Advt_6M_Usd  \
# 0            499 2019-03-31          0.24         0.21         0.23
# 1            449 2019-03-31          0.56         0.54         0.55
# 2             34 2019-03-31          0.58         0.61         0.61
# 3           1117 2019-03-31          0.05         0.04         0.05
# 4            110 2019-03-31          0.21         0.22         0.22
# ...          ...        ...           ...          ...          ...
# 283375       440 1998-11-30          0.68         0.67         0.70
# 283376       884 1998-11-30          0.16         0.16         0.16
# 283377       572 1998-11-30          0.15         0.13         0.12
# 283378       174 1998-11-30          0.22         0.15         0.23
# 283379       752 1998-11-30          0.41         0.38         0.45
#
#         Asset_Turnover  Bb_Yld    Bv  Capex_Ps_Cf  Capex_Sales  ...  \
# 0                 0.90    0.28  0.29         0.41         0.38  ...
# ...

# %%
#Divide the data into two parts and name them 'train_data' and 'test data'. 
#The 'train_data' should consist of all the dates before 01/01/2015. 
#The test_data should consist of all the dates from 01/01/2015 to 03/31/2019.

df['date'] = pd.to_datetime(df['date'])
train_data = df[(df['date'] < '2015-01-01') & (df['date'] >= '1998-01-01')] 
test_data = df[(df['date'] >= '2015-01-01') & (df['date'] <= '2019-03-31')]

# %%
train_data
# Out:
#         stock_id       date  Advt_12M_Usd  Advt_3M_Usd  Advt_6M_Usd  \
# 0             13 2006-12-31          0.25         0.33         0.27
# 1             13 2007-01-31          0.25         0.32         0.28
# 2             13 2007-02-28          0.26         0.30         0.30
# 30            29 2002-09-30          0.43         0.18         0.28
# 31            29 2002-10-31          0.41         0.18         0.23
# ...          ...        ...           ...          ...          ...
# 283375      1205 2004-05-31          0.97         0.97         0.98
# 283376      1205 2004-07-31          0.97         0.96         0.98
# 283377      1205 2004-08-31          0.97         0.96         0.97
# 283378      1205 2004-09-30          0.97         0.96         0.97
# 283379       292 2000-04-30          0.41         0.63         0.52
#
#         Asset_Turnover  Bb_Yld    Bv  Capex_Ps_Cf  Capex_Sales  ...  \
# 0                 0.22    0.33  0.01         0.13         0.84  ...
# ...

# %%
test_data
# Out:
#         stock_id       date  Advt_12M_Usd  Advt_3M_Usd  Advt_6M_Usd  \
# 3             17 2015-03-31          0.73         0.64         0.70
# 4             17 2015-04-30          0.72         0.62         0.66
# 5             17 2015-05-31          0.71         0.63         0.64
# 6             17 2015-06-30          0.70         0.62         0.63
# 7             17 2015-07-31          0.68         0.56         0.60
# ...          ...        ...           ...          ...          ...
# 283364      1158 2018-09-30          0.99         0.99         0.99
# 283365      1158 2018-10-31          0.99         0.99         0.99
# 283366      1158 2018-11-30          0.99         0.99         0.99
# 283367      1158 2018-12-31          0.99         0.99         0.99
# 283368      1158 2019-01-31          0.99         0.99         0.99
#
#         Asset_Turnover  Bb_Yld    Bv  Capex_Ps_Cf  Capex_Sales  ...  \
# 3                 0.40    0.47  0.01         0.70         0.74  ...
# ...

# %%
#checking if x.shape[0] + y.shape[0]  is equal to df.shape[0]
if x.shape[0] + y.shape[0] == df.shape[0]:
    print('True')
else:
    print('False')
# Out:
# True

# %%
#Print the descriptive statistics of ‘train_data’ and ‘test_data’ of the variables listed in Task 4.
train_data[['Asset_Turnover', 'Interest_Expense', 'Eps', 'Net_Margin', 'Roa', 'Roe', 'Ta','Total_Debt', 'R1M_Usd']].describe()
# Out:
#        Asset_Turnover  Interest_Expense            Eps     Net_Margin  \
# count   225467.000000     225467.000000  225467.000000  225467.000000
# mean         0.501975          0.497109       0.501957       0.503767
# std          0.286853          0.273102       0.286755       0.288497
# min          0.010000          0.010000       0.010000       0.010000
# 25%          0.260000          0.270000       0.250000       0.250000
# 50%          0.500000          0.500000       0.500000       0.500000
# 75%          0.750000          0.720000       0.750000       0.750000
# max          1.000000          1.000000       1.000000       1.000000
#
#                  Roa            Roe             Ta     Total_Debt  \
# count  225467.000000  225467.000000  225467.000000  225467.000000
# mean        0.502822       0.497920       0.501697       0.501722
# std         0.286118       0.282243       0.288419       0.288304
# min         0.010000       0.010000       0.010000       0.010000
# ...

# %%
test_data[['Asset_Turnover', 'Interest_Expense', 'Eps', 'Net_Margin', 'Roa', 'Roe', 'Ta','Total_Debt', 'R1M_Usd']].describe()
# Out:
#        Asset_Turnover  Interest_Expense           Eps    Net_Margin  \
# count    57913.000000      57913.000000  57913.000000  57913.000000
# mean         0.503361          0.490858      0.503711      0.504433
# std          0.289536          0.282817      0.286963      0.288825
# min          0.010000          0.010000      0.010000      0.010000
# 25%          0.250000          0.250000      0.260000      0.250000
# 50%          0.500000          0.500000      0.500000      0.500000
# 75%          0.750000          0.730000      0.750000      0.760000
# max          1.000000          1.000000      1.000000      1.000000
#
#                 Roa           Roe            Ta    Total_Debt       R1M_Usd
# count  57913.000000  57913.000000  57913.000000  57913.000000  57913.000000
# mean       0.503225      0.495048      0.499995      0.499056      0.010183
# std        0.287933      0.282022      0.288561      0.288360      0.216750
# ...
